# %%
#Time series data of HD50896 from TESS - 1st part
import os, sys

import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import matplotlib.ticker as ticker

import numpy as np

import astropy
from astropy.io import fits
from astropy.io import ascii
import astropy.units as u
# from astropy.utils.data import get_pkg_data_filename   #time-series extraction tool
# from astropy.timeseries import TimeSeries

import lightkurve as lk    #good time-series library

import pandas as pd 

from scipy.optimize import curve_fit

# %%
#read from manually downloaded data from MAST
wr3_lc1 = lk.read('tess2019306063752-s0018-0000000453305574-0162-s_lc.fits')
wr3_lc1
# Out:
# <TessLightCurve length=16447 LABEL="TIC 453305574" SECTOR=18 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#       object          float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1790.6607644771368  1.0014849e+04 ... -8.8317364e-02 -8.4896972e-03
# 1790.6621533826685  9.9936670e+03 ... -8.7896198e-02 -2.3842925e-02
# 1790.6635422882014  1.0036975e+04 ... -8.6646967e-02 -1.3086200e-02
# 1790.6649311937347  1.0024255e+04 ... -8.4950604e-02 -1.4738259e-02
# 1790.6663200992673  1.0028894e+04 ... -8.8400729e-02 -3.0627981e-02
# 1790.6677090047995  1.0043854e+04 ... -8.7382697e-02 -1.1165801e-02
# 1790.6690979103312  1.0031985e+04 ... -8.7617755e-02 -1.0196708e-02
# 1790.6704868158638  1.0055955e+04 ... -8.7105960e-02 -1.7876882e-02
# 1790.6718757213966  1.0048155e+04 ... -8.4592290e-02 -1.2290231e-02
#                ...            ... ...            ...            ...
# 1815.0217141049222            nan ...            nan            nan
# 1815.0231029680788            nan ...            nan            nan
# 1815.0244918312358            nan ...            nan            nan
# 1815.0258806948589            nan ...            nan            nan
#  1815.027269558017            nan ...            nan            nan
# 1815.0286584211747            nan ...            nan            nan
# 1815.0300472847969            nan ...            nan            nan
# 1815.0314361479543            nan ...            nan            nan
# 1815.0328250111118            nan ...            nan            nan
# 1815.0342138747349            nan ...            nan            nan

# %%
wr3_lc1.filename
# Out:
# 'tess2019306063752-s0018-0000000453305574-0162-s_lc.fits'

# %% [markdown]
# Trying to obtain the PDCSAP flux from the time series. However, a little bit of context first.
#
# - **SAP light curve** is summing together the brightness of pixels that fall within an aperture set by any of these survey missions - referred to as the **optimal aperture**, though, still subject to systematic artifacts of the respective mission.
#
# - **PDCSAP light curve** has more treatment than SAP. The PDCSAP pipeline attempts to remove systematic artifacts while keeping planetary transits intact (made with planet detection intentions)

# %%
ax = wr3_lc1.plot(column='pdcsap_flux', label='PDCSAP Flux', color='teal', normalize=True)    #PDCSAP flux
ax.set_title('PDCSAP Light Curve of WR3 - ts1')
#hd_lc1.plot(column='sap_flux', label='SAP Flux', color='r', normalize=True, ax=ax);    #SAP flux
#ax.set_xlim(1470, 1471)
#ax.set_ylim(1.005, 1.01)
# Out:
# Text(0.5, 1.0, 'PDCSAP Light Curve of WR3 - ts1')

# %%
#timeseries's metadata
wr3_lc1.meta
# Out:
# {'INHERIT': True,
#  'EXTNAME': 'PRIMARY',
#  'EXTVER': 1,
#  'SIMDATA': False,
#  'TELESCOP': 'TESS',
#  'INSTRUME': 'TESS Photometer',
#  'OBJECT': 'TIC 453305574',
#  'TICID': 453305574,
#  'RADESYS': 'ICRS',
#  'RA_OBJ': 24.7317797935727,
#  'DEC_OBJ': 58.1562977287384,
#  'EQUINOX': 2000.0,
#  'EXPOSURE': 19.291672163297,
#  'TIMEREF': 'SOLARSYSTEM',
#  'TASSIGN': 'SPACECRAFT',
#  'TIMESYS': 'TDB',
#  'BJDREFI': 2457000,
#  'BJDREFF': 0.0,
#  'TIMEUNIT': 'd',
#  'TELAPSE': 24.358171923355,
#  'LIVETIME': 19.291672163297186,
#  'TSTART': 1790.660070139879,
#  'TSTOP': 1815.018241831752,
#  'DATE-OBS': '2019-11-03T03:49:20.876',
#  'DATE-END': '2019-11-27T12:25:06.910',
#  'DEADC': 0.792,
#  'TIMEPIXR': 0.5,
#  'TIERRELA': 1.16e-05,
#  'INT_TIME': 1.98,
#  'READTIME': 0.02,
#  'FRAMETIM': 2.0,
#  'NUM_FRM': 60,
#  'TIMEDEL': 0.001388888888888889,
#  'BACKAPP': True,
#  'DEADAPP': True,
#  'VIGNAPP': True,
#  'GAINA': 5.21999979019165,
#  'GAINB': 5.28000020980835,
#  'GAINC': 5.320000171661377,
#  'GAIND': 5.21999979019165,
#  'READNOIA': 10.074599266052246,
#  'READNOIB': 7.761600494384766,
#  'READNOIC': 7.660800457000732,
#  'READNOID': 9.448199272155762,
#  'NREADOUT': 48,
#  'FXDOFF': 209700,
#  'CDPP0_5': 1903.06335449,
#  'CDPP1_0': 2134.18701172,
#  'CDPP2_0': 2371.6484375,
#  'CROWDSAP': 0.98363215,
#  'FLFRCSAP': 0.83059293,
#  'NSPSDDET': 0,
#  'NSPSDCOR': 0,
#  'PDCVAR': 4.421510218169822,
#  'PDCMETHD': 'msMAP',
#  'NUMBAND': 3,
#  'FITTYPE1': 'reducedRobust',
#  'PR_GOOD1': 0.7178067564964294,
#  'PR_WGHT1': 0.0,
#  'FITTYPE2': 'prior',
#  'PR_GOOD2': 0.04244271665811539,
#  'PR_WGHT2': 24.95018196105957,
#  'FITTYPE3': 'prior',
#  'PR_GOOD3': 0.8053699135780334,
#  'PR_WGHT3': 473.44110107421875,
#  'PDC_TOT': 0.9889194965362549,
#  'PDC_TOTP': 44.20465850830078,
#  'PDC_COR': 0.9944241046905518,
#  'PDC_CORP': 60.47237777709961,
#  'PDC_VAR': <astropy.io.fits.card.Undefined at 0x1ed3bcc0100>,
#  'PDC_VARP': <astropy.io.fits.card.Undefined at 0x1ed3bcc0100>,
#  'PDC_NOI': 0.9725483655929565,
#  'PDC_NOIP': 16.697429656982422,
#  'PDC_EPT': <astropy.io.fits.card.Undefined at 0x1ed3bcc0100>,
#  'PDC_EPTP': <astropy.io.fits.card.Undefined at 0x1ed3bcc0100>,
#  'CHECKSUM': '9KnmJHkl9HklGHkl',
#  'TMOFST22': 1.5199999809265137,
#  'MEANBLCA': 6790,
#  'MEANBLCB': 6787,
#  'MEANBLCC': 6689,
#  'MEANBLCD': 6535,
#  'SIMPLE': True,
#  'BITPIX': 8,
#  'NAXIS': 0,
#  'EXTEND': True,
#  'NEXTEND': 2,
#  'ORIGIN': 'NASA/Ames',
#  'DATE': '2020-04-16',
#  'CREATOR': '21666 LightCurveExporterPipelineModule',
#  'PROCVER': 'spoc-4.0.29-20200410',
#  'FILEVER': '1.0',
#  'TIMVERSN': 'OGIP/93-003',
#  'DATA_REL': 30,
#  'SECTOR': 18,
#  'CAMERA': 2,
#  'CCD': 2,
#  'PXTABLE': 181,
#  'PMRA': -4.06006,
#  'PMDEC': -1.42172,
#  'PMTOTAL': 4.30178741,
#  'TESSMAG': 10.53660011,
#  'TEFF': 12307.0,
#  'LOGG': None,
#  'MH': None,
#  'RADIUS': None,
#  'TICVER': 8,
#  'CRMITEN': True,
#  'CRBLKSZ': 10,
#  'CRSPOC': False,
#  'LABEL': 'TIC 453305574',
#  'MISSION': 'TESS',
#  'RA': 24.7317797935727,
#  'DEC': 58.1562977287384,
#  'FILENAME': 'tess2019306063752-s0018-0000000453305574-0162-s_lc.fits',
#  'FLUX_ORIGIN': 'pdcsap_flux',
#  'AUTHOR': 'SPOC',
#  'TARGETID': 453305574,
#  'QUALITY_BITMASK': 'default',
#  'QUALITY_MASK': array([False, False, False, ...,  True,  True,  True])}

# %% [markdown]
# ### Lomb-Scargle Periodogram of WR3

# %%
#Lomb-Scargle Periodogram - normalised to parts per million
pg_wr3_lc1 = wr3_lc1.normalize(unit='ppm').to_periodogram()
pg_wr3_lc1
# Out:
# LombScarglePeriodogram(ID: TIC 453305574)

# %%
#Inspecting the periodogram
ax = pg_wr3_lc1.plot(view='frequency', scale='log')
#ax.set_xlim(0,20)
ax.set_title('Lomb-Scargle periodogram - normal')
plt.savefig('LS_lc1_log')

# %%
pg_wr3_lc1.period_at_max_power   #period at max power
# Out:
# <Quantity 0.42108772 d>

# %%
#Folding light curve using max power period
wr3_lc1.fold(period=pg_wr3_lc1.period_at_max_power).scatter()

# %%
#Testing with folding params & then remaking periodogram
wr3_lc1.fold(period=4.03*pg_wr3_lc1.period_at_max_power, wrap_phase=0.2).scatter()
plt.title('WR3_lc1 - 4.03*period_max - wrap_phase = 0.2')
plt.savefig('wr3_lc1_folded')

# %% [markdown]
# Hmm... Is this the best this star can do in terms of time series??? Ask Ian.

# %%
#Increasing oversampling frequency = 100
pg_wr3_lc1 = wr3_lc1.normalize(unit='ppm').to_periodogram(minimum_period=0.2*u.day, maximum_period=0.5*u.day, oversample_factor=100)
print(pg_wr3_lc1.period_at_max_power)
wr3_lc1.fold(period=pg_wr3_lc1.period_at_max_power).scatter()
plt.title('WR3_lc1 - oversample_f = 100; min_p = 0.2 days, max_p = 0.5 days')
plt.savefig('wr3_lc1_edited_fold')
# Out:
# 0.4210857747151798 d

# %%
#Inspecting LS post-modification
ax = pg_wr3_lc1.plot(view='period', scale='linear')
#ax.set_xlim(0,20)
ax.set_title('Edited LS periodogram - oversample_f = 100; min_p = 0.2 days, max_p = 0.5 days')
plt.savefig('wr3_edited_ls')

# %%
#Writing relevant light curves into ascii files
wr3_lc1.write("wr3_lc1.txt", format="ascii.fixed_width", overwrite=True)
